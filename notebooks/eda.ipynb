# %% [markdown]
# # Exploratory Data Analysis
#
# Placeholder EDA notebook for whichever real dataset(s) you download from Table 1
# of the spec (FMA / MagnaTagATune / GTZAN / DEAM / MusicCaps). Fill in once data
# is in `data/raw/`. Suggested checks:
#
# - Tag / genre frequency distribution (long-tail check -> pick top-K tags)
# - Track duration histogram
# - Artist counts per split (verify no artist leakage between train/val/test)
# - Valence/arousal scatter (DEAM) if using the emotion extension
# - A few waveform / mel-spectrogram / chroma plots via `src/audio_features.py`

# %%
import sys, os
sys.path.insert(0, os.path.abspath('../src'))
import pandas as pd
import matplotlib.pyplot as plt

# Example once you have a metadata CSV in data/raw/, e.g. FMA's tracks.csv:
# df = pd.read_csv('../data/raw/fma_metadata/tracks.csv', index_col=0, header=[0, 1])
# df['track']['genre_top'].value_counts().plot(kind='bar')
print('Load your dataset metadata here once data/raw/ is populated.')
